# %%
# Import packages
import json
import pandas as pd
import numpy as np
import gspread
import datetime as dt

# %%
# Open the JSON file containing the data
with open("output.json", mode="r", encoding='utf-8') as f:
    data = json.load(f)
    data = pd.DataFrame(data)
    f.close()

# %%
# Display the data frame
data.head()
# Out:
#      marke modell variante                                       url_to_crawl  \
# 0  Ferrari    458           https://suchen.mobile.de/fahrzeuge/details.htm...
# 1  Ferrari    458           https://suchen.mobile.de/fahrzeuge/details.htm...
# 2  Ferrari    458           https://suchen.mobile.de/fahrzeuge/details.htm...
# 3  Ferrari    458           https://suchen.mobile.de/fahrzeuge/details.htm...
# 4  Ferrari    458           https://suchen.mobile.de/fahrzeuge/details.htm...
#
#   page_rank  total_num_pages  \
# 0         4                7
# 1         6                7
# 2         6                7
# 3         7                7
# 4         1                7
#
#                                                titel                form  \
# 0  Ferrari 458 Italia KLIMAAUTOMATIK PDC LEDER BI...  Sportwagen / Coupé
# 1              Ferrari 458 Speciale export possible   Sportwagen / Coupé
# 2           Ferrari 458 Speciale Aperta 4.5 V8 605hp   Cabrio / Roadster
# 3                             Ferrari 458 Speciale A   Cabrio / Roadster
# 4  Ferrari 458 Italia/Atelier Car/2y Ferrari Powe...  Sportwagen / Coupé
#
#   farbe   preis  kilometer erstzulassung   getriebe  leistung fahrzeughalter  \
# 0   Rot  169570      66869       11/2011  Automatik       570            2.0
# 1   Rot  429900       4560       01/2014       None       605            2.0
# 2  Gelb  780000       9300       01/2015  Automatik       605            1.0
# 3  None  850000        680       11/2015       None       570            3.0
# 4  Grau  195000      36000       09/2011  Automatik       570            1.0
#
#   standort
# 0       DE
# 1       HU
# 2       ES
# 3       FR
# 4       BE

# %%
# Publish the results to a Google sheet
sa = gspread.service_account()
sh = sa.open("lukas_demo_output_ferrari_458")
wks = sh.add_worksheet(title=f"Output_{dt.datetime.now()}", rows=len(data), cols=len(data.columns))
wks.update([data.columns.values.tolist()] + data.values.tolist()) # Publish the results to the G-sheet
